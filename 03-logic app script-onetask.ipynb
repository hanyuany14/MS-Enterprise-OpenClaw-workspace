# %%
import random
from datetime import datetime, timezone
import httpx

# ===== 1️⃣ 隨機產生 task_id =====
def generate_task_id():
    date_str = datetime.now(timezone.utc).strftime("%Y%m%d")
    rand_num = random.randint(1000, 9999)
    return f"TASK-{date_str}-{rand_num}"

# ===== 2️⃣ 變數 =====
task_id_1 = generate_task_id()
task_id_2 = generate_task_id()
task_id_3 = generate_task_id()
task_id_4 = generate_task_id()

# 為了簡潔，定義一個符合 Schema 的「空」片段
empty_segments = [{"start": "", "end": "", "topic": ""}]

# ===== 3️⃣ Payload =====
payload = {
    "meeting_name": "全球市場進軍啟動會議",
    "meeting_date": datetime.now(timezone.utc).isoformat() + "Z",
    "meeting_id": "MTG-20260325-001",
    "tasks": [



        {
            "task_id": task_id_1,
            "follow_up_task": "為下週第二次會議完成三項準備工作：(1) 查詢後台資料庫整理最近兩個月各週訂單成長率趨勢，判斷熱潮是否持續；(2) 設計支援日美市場的 Azure 雲端架構方案，涵蓋全球部署與彈性伸縮能力；(3) 協調與會者下週共同可用時段並準備會議邀請內容，針對海外擴張、成長率分析、雲端架構與物流方案進行定案。",
            "task_owner": "George",
            "task_owner_email": "admin@MngEnvMCAP352952.onmicrosoft.com",
            "context_summary": "老闆要求 George 於下週第二次會議前完成海外擴張決策所需的完整準備：成長率數據分析作為是否評估海外據點的依據、Azure 基礎架構方案以解決現有機房無法承受流量的問題，並協調下週所有人都能出席的時間召開第二次會議定案。",
            "suggested_ai_actions": [
                "[fabric-data-agent-skill] 查詢後端資料庫得到最近兩個月每週訂單成長率結果",
                "[azure-diagrams-tips] 產出支援日美市場的 Azure 架構圖草案",
                "[ms-graph-calendar] 查詢與會者下週的共同可用時段,草擬會前通知信並建立Teams會議邀請"
            ],
            "related_people": [
                {
                    "name": "Stephen",
                    "role": "主持人／決策者",
                    "email": "csuintern2@MngEnvMCAP352952.onmicrosoft.com",
                    "relevance": "根據成長率分析與雲端架構方案決定海外據點評估，並要求下週召開第二次會議定案"
                },
                {
                    "name": "Kurt",
                    "role": "營運主管",
                    "email": "csuintern@MngEnvMCAP352952.onmicrosoft.com",
                    "relevance": "需出席第二次會議說明物流方案"
                }
            ],
            "transcript_segments": empty_segments,
            "task_status": "Pending"
        },     
        {
            "task_id": task_id_3,
            "follow_up_task": "與 Contoso 外送平台洽談導入其 AI 調度方案，評估是否能改善配送延遲問題。",
            "task_owner": "Kurt",
            "task_owner_email": "csuintern@MngEnvMCAP352952.onmicrosoft.com",
            "context_summary": "Kurt 表示配送延遲已是明顯營運問題，需洽談 AI 調度方案。",
            "suggested_ai_actions": ["[ms-graph-todo] 將此任務加入 Microsoft To Do"],
            "related_people": [
                {"name": "Stephen", "role": "主持人／決策者", "email" : "csuintern2@MngEnvMCAP352952.onmicrosoft.com", "relevance": "關注配送延遲對品牌的影響"}
            ],
            "transcript_segments": empty_segments,
            "task_status": "Pending"
        }        
    ]
}

# ===== 4️⃣ 呼叫 Logic App =====
import os
from dotenv import load_dotenv

load_dotenv()
url = os.environ["LOGIC_APP_CALLBACK_URL"]

try:
    response = httpx.post(
        url, 
        headers={"Content-Type": "application/json"}, 
        json=payload, 
        timeout=30.0
    )
    response.raise_for_status()
    print("Status Code:", response.status_code)
    print("Response:", response.text)
except httpx.HTTPStatusError as e:
    print(f"Error response {e.response.status_code}: {e.response.text}")
except Exception as e:
    print(f"An error occurred: {e}")
